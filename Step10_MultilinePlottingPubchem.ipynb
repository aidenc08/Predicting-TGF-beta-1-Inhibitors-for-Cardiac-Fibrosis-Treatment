# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['font.size'] = 10
plt.rcParams['svg.fonttype'] = 'none'

# %%
import pandas as pd
path = "/content/drive/Shareddrives/1:1_Aiden_Chavda/Results/Accuracy Metric Comparison - Pubchem_R2.csv"

data = pd.read_csv(path)
data.head()
# Out:
#    Epochs/LR   0.00001   0.00005    0.0001    0.0005     0.001     0.005
# 0         10 -3.051592  0.377462  0.514020 -0.045304 -0.023325 -0.053335
# 1         20 -0.027417  0.586595  0.548050 -0.021533 -0.053484 -0.090625
# 2         30  0.050821  0.569565  0.535203 -0.016747 -0.109894 -0.088321
# 3         40  0.519583  0.589183  0.523279 -0.034608 -0.030406 -0.063468
# 4         50  0.555989  0.587453  0.553812 -0.012954 -0.049904 -0.041664

# %%
epochs = list(data["Epochs/LR"])
lr = list(data.columns)
lr = lr[1:]
all_score = []
for index in range(len(epochs)):
  all_score.append(list(data.iloc[index,1:]))

fig, ax = plt.subplots(1,1,figsize=(5,5))
for index in range(len(epochs)):
  ax.plot(lr, all_score[index], label = "Epochs: {}".format(epochs[index]))
ax.set_xlabel("Learning Rate")
ax.set_ylabel("R2 Score")
ax.set_title("R2 Score vs. Learning Rate and Epochs", size = 10)
ax.grid(True)
ax.legend(loc = "best")
plt.savefig("/content/drive/Shareddrives/1:1_Aiden_Chavda/Results/Pubchem_Multiline_Plot.png")
